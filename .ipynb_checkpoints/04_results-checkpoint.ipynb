# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans, AgglomerativeClustering, OPTICS, DBSCAN, cluster_optics_dbscan
from sklearn_extra.cluster import KMedoids
import random
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import euclidean
from sklearn.base import clone
import yfinance as yf
from utils.utils import Portfolio
from utils.helpers import pooled_within_ssd, gen_realizations, gap_statistic, cluster_range, plot_internal, plot_internal_zoom_range, generate_date_combinations
from utils.clusters import kmeans_cluster, kmedoids_cluster, agglomerative_cluster
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers = 6)
from tqdm import tqdm
# Out:
# INFO: Pandarallel will run on 6 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# ### Load Data from YF for S&P500 and save it

# %%
sp500 = Portfolio('2013-01-01', '2024-01-01')
dji = Portfolio('2012-01-01','2024-01-01', file = 'data/dji.csv')
gspc = Portfolio('2012-01-01','2024-01-01', file = 'data/gspc.csv')

# %%
def extract_volatility(row):
    portfolio = Portfolio(row['Buy'], row['Sell'], tickers = eval(row['portfolio']))
    return portfolio.get_portf_volatility()

def load_results(path):
    df = pd.read_csv(path)
    df['volatility'] = df.parallel_apply(extract_volatility, axis = 1) * np.sqrt(252)
    df['sharpe'] = df['sharpe'] * np.sqrt(252)
    df['sortino'] = df['sortino'] * np.sqrt(252)
    df['mean_return'] = df['sharpe'] * df['volatility']
    df['rank'] = df.groupby('Buy')['sharpe'].rank(method='first', ascending=False)
    df = df[df['rank'] == 1].drop(['rank'], axis = 1).set_index('Buy')
    return df

def dji_volatility(row, dji):
    return dji.get_portf_volatility(row['Buy'], row['Sell'])

def random_volatility(row):
    vol = []
    sp500_train = Portfolio('2013-01-01', '2023-01-01')
    for i in range(1000):
        rand_stocks = random.sample(list(sp500_train.stock_sharpe.index), 30)
        random_sharpe.append(sp500_test.get_portf_sharpe(tick = rand_stocks))
        random_sortino.append(sp500_test.get_portf_sortino(tick = rand_stocks))
        random_return.append(sp500_test.get_portf_return(tick = rand_stocks))
        random_volatility.append(sp500_test.get_portf_volatility(tick = rand_stocks))

# %% [markdown]
# ### 10:1 Method Results

# %%
results10 = pd.read_csv('data/addtl/results_10-1.csv')
results10
# Out:
#                       name                   method       metric  stocks  \
# 0       Agg_Comp_30_scaled  Agg. Complete (Returns)      Returns      30
# 1       Agg_Ward_30_scaled      Agg. Ward (Returns)      Returns      30
# 2       Kmedoids_30_scaled      K-Medoids (Returns)      Returns      30
# 3       Kmeans_30_unscaled        K-Means (Returns)      Returns      30
# 4       Kmeans_30_corrdist           K-Means (Corr)  Correlation      30
# 5        Agg_Avg_30_scaled       Agg. Avg (Returns)      Returns      30
# 6     Agg_Comp_30_corrdist     Agg. Complete (Corr)  Correlation      30
# 7     Kmedoids_30_corrdist         K-Medoids (Corr)  Correlation      30
# 8     Agg_Single_30_scaled    Agg. Single (Returns)      Returns      30
# 9      Agg_Avg_30_corrdist          Agg. Avg (Corr)  Correlation      30
# 10                  Random                   Random          NaN      30
# 11  Agg_Single_30_corrdist       Agg. Single (Corr)  Correlation      30
# 12                     DJI                      DJI          NaN      30
#
#     clusters  mean_returns  volatility  sharpe  sortino  actual_return
# 0       30.0        0.4124      0.1822   2.263    3.864         0.5030
# 1       30.0        0.3449      0.1628   2.119    3.084         0.4061
# 2       30.0        0.3501      0.1732   2.021    3.031         0.4132
# 3       30.0        0.3322      0.1768   1.879    2.781         0.3886
# 4       30.0        0.2381      0.1274   1.870    2.680         0.2653
# 5       30.0        0.3112      0.1689   1.842    2.939         0.3600
# 6       30.0        0.2109      0.1235   1.707    2.558         0.2317
# 7       30.0        0.2212      0.1316   1.681    2.534         0.2443
# 8       30.0        0.3027      0.1816   1.667    2.577         0.3486
# 9       30.0        0.2122      0.1452   1.461    2.148         0.2333
# 10       NaN        0.1957      0.1479   1.323    2.106         0.2185
# 11      30.0        0.2083      0.1660   1.255    2.028         0.2286
# 12       NaN        0.1303      0.1142   1.141    1.847         0.1374

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the theme for the plot with a colorblind-friendly palette
sns.set_theme(style="whitegrid", palette='colorblind')

# Create a figure and axis object with specific size
fig, ax = plt.subplots(figsize=(15, 10))

# Use the scatterplot function to build the bubble map with sizes based on Sharpe ratios
scatter = sns.scatterplot(
    data=results10,
    x="mean_returns",
    y="volatility",
    hue='name',  # Assuming 'name' is the column used for coloring points
    size='sharpe',  # Use the 'sharpe' column to set point sizes
    sizes=(100, 1000),  # Define the range for point sizes
    edgecolor='black',  # Dark edge color for better visibility
    linewidth=1.5,    # Slightly thicker edge
    alpha=0.7,  # Adding transparency to the points
    ax=ax,  # Use the specific axis object for plotting
    legend=False
)

# Adding names to each point with a specified font size
for line in range(0, results10.shape[0]):
    plt.text(
        results10["mean_returns"][line],
        results10["volatility"][line],
        results10["method"][line],  # Adjust as needed to the correct column for labels
        horizontalalignment='center',
        verticalalignment='bottom',
        color='black',
        fontsize=12,
        weight='bold'  # Make text bold for better readability
    )

# Add dashed reference lines to indicate mean values
ax.axhline(y=0.15, color='red', alpha=0.5, linestyle='--', linewidth=1)
ax.axvline(x=0.25, color='blue', alpha=0.5, linestyle='--', linewidth=1)

# Set the title and axis labels
ax.set_title('Risk-Return Tradeoff Between Different Portfolios', fontsize=18, weight='bold')
ax.set_ylabel('Risk (Annualized Volatility)', fontsize=14)
ax.set_xlabel('Reward (Expected Returns, 2023)', fontsize=14)
ax.grid(False)
ax.set_xlim(0.1, 0.455)

# Adjust layout to make sure everything fits
plt.tight_layout()

# Save the plot with a transparent background
plt.savefig("data/charts/risk_return_tradeoff.png", transparent=True)

# Show the graph
plt.show()

# %%
results10
# Out:
#                       name                   method       metric  stocks  \
# 0       Agg_Comp_30_scaled  Agg. Complete (Returns)      Returns      30
# 1       Agg_Ward_30_scaled      Agg. Ward (Returns)      Returns      30
# 2       Kmedoids_30_scaled      K-Medoids (Returns)      Returns      30
# 3       Kmeans_30_unscaled        K-Means (Returns)      Returns      30
# 4       Kmeans_30_corrdist           K-Means (Corr)  Correlation      30
# 5        Agg_Avg_30_scaled       Agg. Avg (Returns)      Returns      30
# 6     Agg_Comp_30_corrdist     Agg. Complete (Corr)  Correlation      30
# 7     Kmedoids_30_corrdist         K-Medoids (Corr)  Correlation      30
# 8     Agg_Single_30_scaled    Agg. Single (Returns)      Returns      30
# 9      Agg_Avg_30_corrdist          Agg. Avg (Corr)  Correlation      30
# 10                  Random                   Random          NaN      30
# 11  Agg_Single_30_corrdist       Agg. Single (Corr)  Correlation      30
# 12                     DJI                      DJI          NaN      30
#
#     clusters  mean_returns  volatility  sharpe  sortino  actual_return
# 0       30.0        0.4124      0.1822   2.263    3.864         0.5030
# 1       30.0        0.3449      0.1628   2.119    3.084         0.4061
# 2       30.0        0.3501      0.1732   2.021    3.031         0.4132
# 3       30.0        0.3322      0.1768   1.879    2.781         0.3886
# 4       30.0        0.2381      0.1274   1.870    2.680         0.2653
# 5       30.0        0.3112      0.1689   1.842    2.939         0.3600
# 6       30.0        0.2109      0.1235   1.707    2.558         0.2317
# 7       30.0        0.2212      0.1316   1.681    2.534         0.2443
# 8       30.0        0.3027      0.1816   1.667    2.577         0.3486
# 9       30.0        0.2122      0.1452   1.461    2.148         0.2333
# 10       NaN        0.1957      0.1479   1.323    2.106         0.2185
# 11      30.0        0.2083      0.1660   1.255    2.028         0.2286
# 12       NaN        0.1303      0.1142   1.141    1.847         0.1374

# %%
# Select only the columns 'method', 'stocks', and 'sharpe'
table_data = results10[['method', 'stocks', 'sharpe']]
table_data.columns = ['Portfolio', 'Stocks', 'Sharpe']

# Create a figure and axis object with specific size
fig, ax = plt.subplots(figsize=(8, 3))  # Adjust size based on table content

# Hide the axes
ax.axis('off')

# Create a table
table = ax.table(
    cellText=table_data.values,  # Table data
    colLabels=table_data.columns,  # Column headers
    cellLoc='center',  # Center-align text in cells
    loc='center',  # Position the table in the center of the plot
)

# Set font size for the table
table.auto_set_font_size(False)
table.set_fontsize(10)

# Adjust column widths to provide more space for text
column_widths = [0.4, 0.2, 0.2]  # Adjust these values as needed
for i, width in enumerate(column_widths):
    for j in range(len(table_data) + 1):
        table[(j, i)].set_width(width)

# Adjust vertical padding by setting row heights
for i in range(len(table_data) + 1):  # Include header row
    for j in range(len(table_data.columns)):
        table[(i, j)].set_height(0.15)  # Increase the height of each cell
        table[(i, j)].set_facecolor('none')  # Set background to transparent
        table[(i, j)].set_edgecolor('gray')  # Set border color to gray
        table[(i, j)].set_linewidth(0.5)     # Set border line width

# Make the first column bold
for i in range(1, len(table_data) + 1):  # Start from 1 to skip header
    table[(i, 0)].set_text_props(weight='bold')  # First column is column 0

# Save the table as an image with a transparent background
plt.savefig("data/charts/method_sharpe_table.png", transparent=True, bbox_inches='tight')

# Show the table
plt.show()

# %% [markdown]
# ### Get Returns Plot

# %%
comp5s = load_results('data/complete_scaled_5-1.csv')
ward5s = load_results('data/ward_scaled_5-1.csv')
kmedoids5s = load_results('data/ward_scaled_5-1.csv')
kmeans5u = load_results('data/kmeans_unscaled_5-1.csv')
kmeans5c = load_results('data/kmeans_corrrdist_5-1.csv')
avg5s = load_results('data/avg_scaled_5-1.csv')
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=210), Label(value='0 / 210'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=210), Label(value='0 / 210'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=210), Label(value='0 / 210'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=210), Label(value='0 / 210'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=210), Label(value='0 / 210'))), HB…

# %%
comp5s.to_csv('data/addtl/complte_scaled_new_5-1.csv', index = False)
ward5s.to_csv('data/addtl/ward_scaled_new_5-1.csv', index = False)
kmedoids5s.to_csv('data/addtl/kmedoids_scaled_new_5-1.csv', index = False)
kmeans5u.to_csv('data/addtl/kmeans_unscaled_new_5-1.csv', index = False)
kmeans5c.to_csv('data/addtl/kmeans_corrrdist_new_5-1.csv', index = False)
avg5s.to_csv('data/addtl/avg_scaled_new_5-1.csv', index = False)

# %%
baseline = pd.read_csv('data/addtl/baseline_new_5-1.csv')
baseline['rank'] = baseline.groupby('Buy')['DJI_Sharpe'].rank(method='first', ascending=False)
baseline = baseline[baseline['rank'] == 1].drop(['rank'], axis = 1).set_index('Buy')
baseline[['DJI_Sharpe', 'DJI_Sortino', 'DJI_Volatility', 'Random_Sharpe', 'Random_Sortino', 'Random_Volatility']] = baseline[['DJI_Sharpe', 'DJI_Sortino', 'DJI_Volatility', 'Random_Sharpe', 'Random_Sortino', 'Random_Volatility']] * np.sqrt(252)
baseline['DJI_Mean_Return'] = baseline['DJI_Sharpe']*baseline['DJI_Volatility']
baseline['Random_Mean_Return'] = baseline['Random_Sharpe'] * baseline['Random_Volatility']
baseline
# Out:
#                  Start         End        Sell  DJI_Sharpe  DJI_Sortino  \
# Buy
# 2018-01-03  2013-01-02  2018-01-02  2019-01-03   -0.519429    -0.639970
# 2018-01-04  2013-01-03  2018-01-03  2019-01-04   -0.368411    -0.460980
# 2018-01-05  2013-01-04  2018-01-04  2019-01-07   -0.393703    -0.492176
# 2018-01-09  2013-01-07  2018-01-08  2019-01-09   -0.332549    -0.416201
# 2018-01-10  2013-01-09  2018-01-09  2019-01-10   -0.300973    -0.376567
# ...                ...         ...         ...         ...          ...
# 2022-12-21  2017-12-20  2022-12-20  2023-12-21    0.991499     1.622370
# 2022-12-22  2017-12-21  2022-12-21  2023-12-22    1.083618     1.762275
# 2022-12-23  2017-12-22  2022-12-22  2023-12-26    1.074603     1.746998
# 2022-12-28  2017-12-26  2022-12-27  2023-12-28    1.205681     1.954171
# 2022-12-29  2017-12-28  2022-12-28  2023-12-29    1.113308     1.794732
#
#             DJI_Return  DJI_Volatility  SP500_Sharpe  SP500_Sortino  \
# Buy
# 2018-01-03   -0.089736        0.181729     -0.037119      -0.046407
# 2018-01-04   -0.065482        0.184561     -0.025641      -0.032619
# 2018-01-05   -0.069755        0.184392     -0.025046      -0.031877
# 2018-01-09   -0.059351        0.184723     -0.021600      -0.027547
# 2018-01-10   -0.053893        0.184800     -0.016337      -0.020768
# ...                ...             ...           ...            ...
# 2022-12-21    0.120680        0.115370      0.086849       0.137748
# 2022-12-22    0.131965        0.114846      0.093912       0.148309
# 2022-12-23    0.130750        0.114805      0.093920       0.148322
# 2022-12-28    0.147051        0.114243      0.100681       0.158315
# 2022-12-29    0.134516        0.113813      0.092691       0.145020
#
#             SP500_Return  SP500_Volatility  Random_Sharpe  Random_Sortino  \
# Buy
# 2018-01-03     -0.091616          0.010313      -0.497766       -0.629850
# 2018-01-04     -0.065310          0.010494      -0.295138       -0.385287
# 2018-01-05     -0.063873          0.010499      -0.262580       -0.341459
# 2018-01-09     -0.055441          0.010520      -0.267497       -0.350345
# 2018-01-10     -0.042250          0.010528      -0.192860       -0.252596
# ...                  ...               ...            ...             ...
# 2022-12-21      0.207407          0.008646       1.074985        1.746185
# 2022-12-22      0.225079          0.008612       1.247012        2.001999
# 2022-12-23      0.225101          0.008612       1.262587        2.035949
# 2022-12-28      0.242006          0.008576       1.368700        2.195269
# 2022-12-29      0.219223          0.008520       1.197327        1.916824
#
#             Random_Return  Random_Volatility  DJI_Mean_Return  \
# Buy
# 2018-01-03      -0.081588           0.172764        -0.094395
# 2018-01-04      -0.051378           0.177752        -0.067994
# 2018-01-05      -0.044849           0.174594        -0.072596
# 2018-01-09      -0.046167           0.179063        -0.061429
# 2018-01-10      -0.034268           0.179814        -0.055620
# ...                   ...                ...              ...
# 2022-12-21       0.178792           0.149510         0.114390
# 2022-12-22       0.209897           0.150283         0.124449
# 2022-12-23       0.215125           0.150754         0.123370
# 2022-12-28       0.227030           0.147787         0.137740
# 2022-12-29       0.199672           0.149212         0.126709
#
#             Random_Mean_Return
# Buy
# 2018-01-03           -0.085996
# 2018-01-04           -0.052461
# 2018-01-05           -0.045845
# 2018-01-09           -0.047899
# 2018-01-10           -0.034679
# ...                        ...
# 2022-12-21            0.160721
# 2022-12-22            0.187405
# 2022-12-23            0.190340
# 2022-12-28            0.202276
# 2022-12-29            0.178655
#
# [1049 rows x 17 columns]

# %%
baseline.columns
# Out:
# Index(['Start', 'End', 'Sell', 'DJI_Sharpe', 'DJI_Sortino', 'DJI_Return',
#        'DJI_Volatility', 'SP500_Sharpe', 'SP500_Sortino', 'SP500_Return',
#        'SP500_Volatility', 'Random_Sharpe', 'Random_Sortino', 'Random_Return',
#        'Random_Volatility', 'DJI_Mean_Return', 'Random_Mean_Return'],
#       dtype='object')

# %%
consolidated = baseline[['Start', 'End', 'Sell', 'DJI_Sharpe', 'DJI_Sortino', 'DJI_Return', 'DJI_Volatility', 'DJI_Mean_Return', 
                        'Random_Sharpe', 'Random_Sortino', 'Random_Return', 'Random_Volatility','Random_Mean_Return']]
consolidated[['Comp_Sharpe', 'Agg_Comp_Sortino', 'Agg_Comp_Return', 'Agg_Comp_Volatility', 'Agg_Comp_Mean_Return']] = comp5s[['sharpe', 'sortino', 'return', 'volatility', 'mean_return']]
consolidated[['Comp_Sharpe', 'Agg_Comp_Sortino', 'Agg_Comp_Return', 'Agg_Comp_Volatility', 'Agg_Comp_Mean_Return']] = wards5s[['sharpe', 'sortino', 'return', 'volatility', 'mean_return']]
# Out:
#                  Start         End        Sell  DJI_Sharpe  DJI_Sortino  \
# Buy
# 2018-01-03  2013-01-02  2018-01-02  2019-01-03   -0.032721    -0.040314
# 2018-01-04  2013-01-03  2018-01-03  2019-01-04   -0.023208    -0.029039
# 2018-01-05  2013-01-04  2018-01-04  2019-01-07   -0.024801    -0.031004
# 2018-01-09  2013-01-08  2018-01-08  2019-01-09   -0.020949    -0.026218
# 2018-01-10  2013-01-09  2018-01-09  2019-01-10   -0.018960    -0.023721
# ...                ...         ...         ...         ...          ...
# 2022-12-21  2017-12-20  2022-12-20  2023-12-21    0.062459     0.102200
# 2022-12-22  2017-12-21  2022-12-21  2023-12-22    0.068261     0.111013
# 2022-12-23  2017-12-22  2022-12-22  2023-12-26    0.067694     0.110051
# 2022-12-28  2017-12-26  2022-12-27  2023-12-28    0.075951     0.123101
# 2022-12-29  2017-12-28  2022-12-28  2023-12-29    0.070132     0.113058
#
#             DJI_Return  Random_Sharpe  Random_Sortino  Random_Return  \
# Buy
# 2018-01-03   -0.089736      -0.028551       -0.036491      -0.075246
# 2018-01-04   -0.065482      -0.020965       -0.026933      -0.057112
# 2018-01-05   -0.069755      -0.021065       -0.027641      -0.058040
# 2018-01-09   -0.059351      -0.018152       -0.023729      -0.049600
# 2018-01-10   -0.053893      -0.013452       -0.017833      -0.038470
# ...                ...            ...             ...            ...
# 2022-12-21    0.120680       0.069035        0.112009       0.179115
# 2022-12-22    0.131965       0.084625        0.137498       0.223036
# 2022-12-23    0.130750       0.080037        0.129678       0.217860
# 2022-12-28    0.147051       0.086422        0.138803       0.231924
# 2022-12-29    0.134516       0.078217        0.124768       0.206748
#
#             KMeans_Sharpe  ...  Agg_Avg_Return  Agg_Ward_Sharpe  \
# Buy                        ...
# 2018-01-03      -0.045022  ...       -0.012945        -0.069216
# 2018-01-04      -0.030459  ...        0.048162        -0.059764
# 2018-01-05      -0.024023  ...        0.079600        -0.055798
# 2018-01-09      -0.003910  ...        0.090349        -0.053790
# 2018-01-10      -0.000517  ...        0.088725        -0.045632
# ...                   ...  ...             ...              ...
# 2022-12-21       0.070083  ...        0.240608         0.097474
# 2022-12-22       0.125443  ...        0.276080         0.083974
# 2022-12-23       0.079751  ...        0.285962         0.082182
# 2022-12-28       0.103234  ...        0.335820         0.111493
# 2022-12-29       0.116666  ...        0.293357         0.088678
#
#             Agg_Ward_Sortino  Agg_Ward_Return  Agg_Comp_Sharpe  \
# Buy
# 2018-01-03         -0.096003        -0.219696         0.003304
# 2018-01-04         -0.083186        -0.193962         0.013988
# 2018-01-05         -0.078091        -0.182409         0.020281
# 2018-01-09         -0.075314        -0.176341         0.027356
# 2018-01-10         -0.063665        -0.151479         0.021395
# ...                      ...              ...              ...
# 2022-12-21          0.137445         0.259147         0.097741
# 2022-12-22          0.119909         0.220286         0.110664
# 2022-12-23          0.117563         0.218496         0.107738
# 2022-12-28          0.167251         0.342656         0.118045
# 2022-12-29          0.125385         0.233106         0.101643
#
#             Agg_Comp_Sortino  Agg_Comp_Return  KMed_Sharpe  KMed_Sortino  \
# Buy
# 2018-01-03          0.003977         0.011694    -0.023174     -0.029021
# 2018-01-04          0.017222         0.052864    -0.010683     -0.013665
# 2018-01-05          0.025069         0.075922    -0.006121     -0.007868
# 2018-01-09          0.033713         0.103794     0.000109      0.000140
# 2018-01-10          0.026477         0.080743     0.002548      0.003272
# ...                      ...              ...          ...           ...
# 2022-12-21          0.151424         0.339938     0.084224      0.125140
# 2022-12-22          0.172128         0.390868     0.093179      0.138829
# 2022-12-23          0.168453         0.375960     0.093758      0.139724
# 2022-12-28          0.177539         0.364943     0.105289      0.155548
# 2022-12-29          0.156868         0.311106     0.099145      0.146908
#
#             KMed_Return
# Buy
# 2018-01-03    -0.072913
# 2018-01-04    -0.035021
# 2018-01-05    -0.020316
# 2018-01-09     0.000366
# 2018-01-10     0.008601
# ...                 ...
# 2022-12-21     0.257281
# 2022-12-22     0.285089
# 2022-12-23     0.287168
# 2022-12-28     0.325365
# 2022-12-29     0.302693
#
# [1049 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 6))

consolidated[['DJI_Return', 'Random_Return', 'KMeans_Return', 'Agg_Avg_Return', 'Agg_Ward_Return', 'Agg_Comp_Return',
             'KMed_Return']].plot(ax=ax)

ax.set_title('Simluated 1-Year Portfolio Returns')
ax.set_xlabel('Buy Date')
ax.set_ylabel('Returns')
ax.legend(title='Portfolio')
ax.grid(True)

# Show the plot
plt.show()

# %%
cols = ['DJI_Return', 'Random_Return', 'KMeans_Return', 'Agg_Avg_Return', 'Agg_Ward_Return', 'Agg_Comp_Return', 'KMed_Return']
cols_monthly = []
for k in cols:
    colname = f"{k}_monthly"
    consolidated[colname] = consolidated[k].rolling(window=30).mean()
    cols_monthly.append(colname)

fig, ax = plt.subplots(figsize=(20, 6))

consolidated[cols_monthly].plot(ax=ax)

ax.set_title('Simluated 1-Year Portfolio Returns')
ax.set_xlabel('Buy Date')
ax.set_ylabel('Returns')
ax.legend(title='Portfolio')
ax.grid(True)

# Show the plot
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(15, 6))

# Create violin plots for each column
sns.violinplot(data=consolidated[['DJI_Sharpe', 'Random_Sharpe', 'KMeans_Sharpe', 'Agg_Avg_Sharpe', 'Agg_Ward_Sharpe', 'Agg_Comp_Sharpe', 'KMed_Sharpe']])

# Calculate the median of 'DJI_Sharpe'
dji_median = consolidated['DJI_Sharpe'].median()

# Add a horizontal line for the median of 'DJI_Sharpe'
plt.axhline(y=dji_median, color='blue', linestyle='--', linewidth=1, label=f'DJI Median: {dji_median:.2f}')

# Set new category names
new_category_names = ['DJI', 'Random', 'KMeans', 'Agg. Average', 'Agg. Ward', 'Agg. Complete', 'K-Medoids']
plt.gca().set_xticklabels(new_category_names)

# Customize the plot
plt.title('Distribution of Sharpe Ratios of Each Portfolio')
plt.xlabel('Portfolios')
plt.ylabel('Sharpe Ratio')

# Add legend to show the median line label
plt.legend()

# Display the plot
plt.show()

# %%
# Calculate the median of 'DJI_Sortino'
dji_median = consolidated['DJI_Sortino'].median()

# Create a figure and axis
plt.figure(figsize=(15, 6))

# Create violin plots for each column with Sortino ratios
sns.violinplot(data=consolidated[['DJI_Sortino', 'Random_Sortino', 'KMeans_Sortino', 'Agg_Avg_Sortino', 'Agg_Ward_Sortino', 'Agg_Comp_Sortino', 'KMed_Sortino']])

# Add a horizontal line for the median of 'DJI_Sortino'
plt.axhline(y=dji_median, color='blue', linestyle='--', linewidth=1, label=f'DJI Median: {dji_median:.2f}')

# Set new category names
new_category_names = ['DJI', 'Random', 'KMeans', 'Agg. Average', 'Agg. Ward', 'Agg. Complete', 'K-Medoids']
plt.gca().set_xticklabels(new_category_names)

# Customize the plot
plt.title('Distribution of Sortino Ratios of Each Portfolio')
plt.xlabel('Portfolios')
plt.ylabel('Sortino Ratio')

# Add legend to show the median line label
plt.legend()

# Display the plot
plt.show()

# %%
# Calculate the median of 'DJI_Return'
dji_median_return = consolidated['DJI_Return'].median()

# Create a figure and axis
plt.figure(figsize=(15, 6))

# Create violin plots for each column with Returns
sns.violinplot(data=consolidated[['DJI_Return', 'Random_Return', 'KMeans_Return', 'Agg_Avg_Return', 'Agg_Ward_Return', 'Agg_Comp_Return', 'KMed_Return']])

# Add a horizontal line for the median of 'DJI_Return'
plt.axhline(y=dji_median_return, color='blue', linestyle='--', linewidth=1, label=f'DJI Median Return: {dji_median_return:.2f}')

# Set new category names
new_category_names = ['DJI', 'Random', 'KMeans', 'Agg. Average', 'Agg. Ward', 'Agg. Complete', 'K-Medoids']
plt.gca().set_xticklabels(new_category_names)

# Customize the plot
plt.title('Distribution of Returns of Each Portfolio')
plt.xlabel('Portfolios')
plt.ylabel('Returns')

# Add legend to show the median return line label
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
from scipy.stats import wilcoxon

def perform_wilcoxon_test(column1, column2, column1_name='Column 1', column2_name='Column 2', alpha=0.05):
    """
    Perform a Wilcoxon signed-rank test to compare two columns of data.
    
    Parameters:
    - column1: array-like, the first set of data (e.g., Sortino or Sharpe ratios for KMeans).
    - column2: array-like, the second set of data (e.g., Sortino or Sharpe ratios for DJI).
    - column1_name: str, name of the first column (default is 'Column 1').
    - column2_name: str, name of the second column (default is 'Column 2').
    - alpha: float, significance level (default is 0.05).
    
    Returns:
    - None, but prints out the results of the hypothesis test.
    """
    # Calculate the differences
    differences = column1 - column2
    
    # Perform the Wilcoxon signed-rank test
    statistic, p_value = wilcoxon(differences, alternative='greater')
    
    # Display results
    print(f"Wilcoxon test comparing {column1_name} and {column2_name}")
    print(f"Wilcoxon test statistic: {statistic}")
    print(f"P-value: {p_value}")
    
    # Conclusion based on p-value
    if p_value < alpha:
        print(f"Reject the null hypothesis: {column1_name} has significantly higher values than {column2_name}.")
    else:
        print(f"Fail to reject the null hypothesis: No significant difference in values between {column1_name} and {column2_name}.")

# %%
# Perform the Wilcoxon test for Sortino ratios
perform_wilcoxon_test(
    consolidated['KMeans_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='KMeans Sortino', 
    column2_name='DJI Sortino'
)

perform_wilcoxon_test(
    consolidated['Agg_Avg_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='Agg_Avg Sortino', 
    column2_name='DJI Sortino'
)

perform_wilcoxon_test(
    consolidated['Agg_Ward_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='Agg_Ward Sortino', 
    column2_name='DJI Sortino'
)

perform_wilcoxon_test(
    consolidated['Agg_Comp_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='Agg_Comp Sortino', 
    column2_name='DJI Sortino'
)

perform_wilcoxon_test(
    consolidated['KMed_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='KMed Sortino', 
    column2_name='DJI Sortino'
)

# Perform the Wilcoxon test for Sharpe ratios
perform_wilcoxon_test(
    consolidated['KMeans_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='KMeans Sharpe', 
    column2_name='DJI Sharpe'
)

perform_wilcoxon_test(
    consolidated['Agg_Avg_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='Agg_Avg Sharpe', 
    column2_name='DJI Sharpe'
)

perform_wilcoxon_test(
    consolidated['Agg_Ward_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='Agg_Ward Sharpe', 
    column2_name='DJI Sharpe'
)

perform_wilcoxon_test(
    consolidated['Agg_Comp_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='Agg_Comp Sharpe', 
    column2_name='DJI Sharpe'
)

perform_wilcoxon_test(
    consolidated['KMed_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='KMed Sharpe', 
    column2_name='DJI Sharpe'
)

# Perform the Wilcoxon test for Returns
perform_wilcoxon_test(
    consolidated['KMeans_Return'], 
    consolidated['DJI_Return'], 
    column1_name='KMeans Return', 
    column2_name='DJI Return'
)

perform_wilcoxon_test(
    consolidated['Agg_Avg_Return'], 
    consolidated['DJI_Return'], 
    column1_name='Agg_Avg Return', 
    column2_name='DJI Return'
)

perform_wilcoxon_test(
    consolidated['Agg_Ward_Return'], 
    consolidated['DJI_Return'], 
    column1_name='Agg_Ward Return', 
    column2_name='DJI Return'
)

perform_wilcoxon_test(
    consolidated['Agg_Comp_Return'], 
    consolidated['DJI_Return'], 
    column1_name='Agg_Comp Return', 
    column2_name='DJI Return'
)

perform_wilcoxon_test(
    consolidated['KMed_Return'], 
    consolidated['DJI_Return'], 
    column1_name='KMed Return', 
    column2_name='DJI Return'
)
# Out:
# Wilcoxon test comparing KMeans Sortino and DJI Sortino
# Wilcoxon test statistic: 401504.0
# P-value: 4.1838839100286e-38
# Reject the null hypothesis: KMeans Sortino has significantly higher values than DJI Sortino.
# Wilcoxon test comparing Agg_Avg Sortino and DJI Sortino
# Wilcoxon test statistic: 366481.0
# P-value: 8.180598991456655e-21
# Reject the null hypothesis: Agg_Avg Sortino has significantly higher values than DJI Sortino.
# Wilcoxon test comparing Agg_Ward Sortino and DJI Sortino
# Wilcoxon test statistic: 347317.0
# P-value: 1.1405191255122282e-13
# Reject the null hypothesis: Agg_Ward Sortino has significantly higher values than DJI Sortino.
# Wilcoxon test comparing Agg_Comp Sortino and DJI Sortino
# Wilcoxon test statistic: 372434.0
# P-value: 2.2936306942069116e-23
# Reject the null hypothesis: Agg_Comp Sortino has significantly higher values than DJI Sortino.
# Wilcoxon test comparing KMed Sortino and DJI Sortino
# Wilcoxon test statistic: 400192.0
# P-value: 2.3351176408652383e-37
# Reject the null hypothesis: KMed Sortino has significantly higher values than DJI Sortino.
# Wilcoxon test comparing KMeans Sharpe and DJI Sharpe
# Wilcoxon test statistic: 405812.0
# P-value: 1.3043843482040197e-40
# Reject the null hypothesis: KMeans Sharpe has significantly higher values than DJI Sharpe.
# Wilcoxon test comparing Agg_Avg Sharpe and DJI Sharpe
# Wilcoxon test statistic: 372726.0
# P-value: 1.703190971658734e-23
# Reject the null hypothesis: Agg_Avg Sharpe has significantly higher values than DJI Sharpe.
# Wilcoxon test comparing Agg_Ward Sharpe and DJI Sharpe
# Wilcoxon test statistic: 353447.0
# P-value: 8.901539403477072e-16
# Reject the null hypothesis: Agg_Ward Sharpe has significantly higher values than DJI Sharpe.
# Wilcoxon test comparing Agg_Comp Sharpe and DJI Sharpe
# Wilcoxon test statistic: 376707.0
# P-value: 2.6977454345781164e-25
# Reject the null hypothesis: Agg_Comp Sharpe has significantly higher values than DJI Sharpe.
# Wilcoxon test comparing KMed Sharpe and DJI Sharpe
# Wilcoxon test statistic: 400992.0
# P-value: 8.201701959527777e-38
# Reject the null hypothesis: KMed Sharpe has significantly higher values than DJI Sharpe.
# Wilcoxon test comparing KMeans Return and DJI Return
# Wilcoxon test statistic: 475042.0
# P-value: 2.5883610980282413e-92
# Reject the null hypothesis: KMeans Return has significantly higher values than DJI Return.
# Wilcoxon test comparing Agg_Avg Return and DJI Return
# Wilcoxon test statistic: 468872.0
# P-value: 7.855475859772543e-87
# Reject the null hypothesis: Agg_Avg Return has significantly higher values than DJI Return.
# Wilcoxon test comparing Agg_Ward Return and DJI Return
# Wilcoxon test statistic: 464021.0
# P-value: 1.2166227406553994e-82
# Reject the null hypothesis: Agg_Ward Return has significantly higher values than DJI Return.
# Wilcoxon test comparing Agg_Comp Return and DJI Return
# Wilcoxon test statistic: 457481.0
# P-value: 3.685613287112778e-77
# Reject the null hypothesis: Agg_Comp Return has significantly higher values than DJI Return.
# Wilcoxon test comparing KMed Return and DJI Return
# Wilcoxon test statistic: 493257.0
# P-value: 1.697253301756658e-109
# Reject the null hypothesis: KMed Return has significantly higher values than DJI Return.

# %%
from scipy.stats import binomtest

def perform_binomial_test(column1, column2, column1_name='Column 1', column2_name='Column 2', alpha=0.05):
    """
    Perform a binomial test to compare the number of times one metric is greater than another.
    
    Parameters:
    - column1: array-like, the first set of data (e.g., returns, Sortino or Sharpe ratios for KMeans).
    - column2: array-like, the second set of data (e.g., returns, Sortino or Sharpe ratios for DJI).
    - column1_name: str, name of the first column (default is 'Column 1').
    - column2_name: str, name of the second column (default is 'Column 2').
    - alpha: float, significance level (default is 0.05).
    
    Returns:
    - None, but prints out the results of the hypothesis test.
    """
    # Count the number of times column1 is greater than column2
    successes = (column1 > column2).sum()
    n = len(column1)
    
    # Perform the binomial test using scipy.stats.binomtest
    test_result = binomtest(successes, n, p=0.5, alternative='greater')
    p_value = test_result.pvalue
    
    # Display results
    print(f"Binomial test comparing {column1_name} and {column2_name}")
    print(f"Number of successes: {successes} out of {n}: {successes*100/n:.2f}")
    print(f"P-value: {p_value}")
    
    # Conclusion based on p-value
    if p_value < alpha:
        print(f"Reject the null hypothesis: {column1_name} has significantly more periods with higher values than {column2_name}.")
    else:
        print(f"Fail to reject the null hypothesis: No significant difference in the number of periods with higher values between {column1_name} and {column2_name}.")

# %%
# Example usage for Returns
perform_binomial_test(
    consolidated['KMeans_Return'], 
    consolidated['DJI_Return'], 
    column1_name='KMeans Return', 
    column2_name='DJI Return'
)

perform_binomial_test(
    consolidated['Agg_Avg_Return'], 
    consolidated['DJI_Return'], 
    column1_name='Agg_Avg Return', 
    column2_name='DJI Return'
)

perform_binomial_test(
    consolidated['Agg_Ward_Return'], 
    consolidated['DJI_Return'], 
    column1_name='Agg_Ward Return', 
    column2_name='DJI Return'
)

perform_binomial_test(
    consolidated['Agg_Comp_Return'], 
    consolidated['DJI_Return'], 
    column1_name='Agg_Comp Return', 
    column2_name='DJI Return'
)

perform_binomial_test(
    consolidated['KMed_Return'], 
    consolidated['DJI_Return'], 
    column1_name='KMed Return', 
    column2_name='DJI Return'
)

# Example usage for Sortino ratios
perform_binomial_test(
    consolidated['KMeans_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='KMeans Sortino', 
    column2_name='DJI Sortino'
)

perform_binomial_test(
    consolidated['Agg_Avg_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='Agg_Avg Sortino', 
    column2_name='DJI Sortino'
)

perform_binomial_test(
    consolidated['Agg_Ward_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='Agg_Ward Sortino', 
    column2_name='DJI Sortino'
)

perform_binomial_test(
    consolidated['Agg_Comp_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='Agg_Comp Sortino', 
    column2_name='DJI Sortino'
)

perform_binomial_test(
    consolidated['KMed_Sortino'], 
    consolidated['DJI_Sortino'], 
    column1_name='KMed Sortino', 
    column2_name='DJI Sortino'
)

# Example usage for Sharpe ratios
perform_binomial_test(
    consolidated['KMeans_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='KMeans Sharpe', 
    column2_name='DJI Sharpe'
)

perform_binomial_test(
    consolidated['Agg_Avg_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='Agg_Avg Sharpe', 
    column2_name='DJI Sharpe'
)

perform_binomial_test(
    consolidated['Agg_Ward_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='Agg_Ward Sharpe', 
    column2_name='DJI Sharpe'
)

perform_binomial_test(
    consolidated['Agg_Comp_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='Agg_Comp Sharpe', 
    column2_name='DJI Sharpe'
)

perform_binomial_test(
    consolidated['KMed_Sharpe'], 
    consolidated['DJI_Sharpe'], 
    column1_name='KMed Sharpe', 
    column2_name='DJI Sharpe'
)
# Out:
# Binomial test comparing KMeans Return and DJI Return
# Number of successes: 803 out of 1049: 76.55
# P-value: 9.50375491248203e-70
# Reject the null hypothesis: KMeans Return has significantly more periods with higher values than DJI Return.
# Binomial test comparing Agg_Avg Return and DJI Return
# Number of successes: 783 out of 1049: 74.64
# P-value: 6.460868880430682e-60
# Reject the null hypothesis: Agg_Avg Return has significantly more periods with higher values than DJI Return.
# Binomial test comparing Agg_Ward Return and DJI Return
# Number of successes: 784 out of 1049: 74.74
# P-value: 2.186470848348458e-60
# Reject the null hypothesis: Agg_Ward Return has significantly more periods with higher values than DJI Return.
# Binomial test comparing Agg_Comp Return and DJI Return
# Number of successes: 768 out of 1049: 73.21
# P-value: 4.074428826660148e-53
# Reject the null hypothesis: Agg_Comp Return has significantly more periods with higher values than DJI Return.
# Binomial test comparing KMed Return and DJI Return
# Number of successes: 838 out of 1049: 79.89
# P-value: 3.340443075612794e-89
# Reject the null hypothesis: KMed Return has significantly more periods with higher values than DJI Return.
# Binomial test comparing KMeans Sortino and DJI Sortino
# Number of successes: 711 out of 1049: 67.78
# P-value: 1.8145284405836186e-31
# Reject the null hypothesis: KMeans Sortino has significantly more periods with higher values than DJI Sortino.
# Binomial test comparing Agg_Avg Sortino and DJI Sortino
# Number of successes: 610 out of 1049: 58.15
# P-value: 7.203125878099119e-08
# Reject the null hypothesis: Agg_Avg Sortino has significantly more periods with higher values than DJI Sortino.
# Binomial test comparing Agg_Ward Sortino and DJI Sortino
# Number of successes: 637 out of 1049: 60.72
# P-value: 1.929548292175278e-12
# Reject the null hypothesis: Agg_Ward Sortino has significantly more periods with higher values than DJI Sortino.
# Binomial test comparing Agg_Comp Sortino and DJI Sortino
# Number of successes: 636 out of 1049: 60.63
# P-value: 2.9971492863654358e-12
# Reject the null hypothesis: Agg_Comp Sortino has significantly more periods with higher values than DJI Sortino.
# Binomial test comparing KMed Sortino and DJI Sortino
# Number of successes: 718 out of 1049: 68.45
# P-value: 8.756486245799724e-34
# Reject the null hypothesis: KMed Sortino has significantly more periods with higher values than DJI Sortino.
# Binomial test comparing KMeans Sharpe and DJI Sharpe
# Number of successes: 693 out of 1049: 66.06
# P-value: 6.226189070347814e-26
# Reject the null hypothesis: KMeans Sharpe has significantly more periods with higher values than DJI Sharpe.
# Binomial test comparing Agg_Avg Sharpe and DJI Sharpe
# Number of successes: 619 out of 1049: 59.01
# P-value: 2.945485387967002e-09
# Reject the null hypothesis: Agg_Avg Sharpe has significantly more periods with higher values than DJI Sharpe.
# Binomial test comparing Agg_Ward Sharpe and DJI Sharpe
# Number of successes: 627 out of 1049: 59.77
# P-value: 1.3231714667773698e-10
# Reject the null hypothesis: Agg_Ward Sharpe has significantly more periods with higher values than DJI Sharpe.
# Binomial test comparing Agg_Comp Sharpe and DJI Sharpe
# Number of successes: 652 out of 1049: 62.15
# P-value: 1.6256887221887893e-15
# Reject the null hypothesis: Agg_Comp Sharpe has significantly more periods with higher values than DJI Sharpe.
# Binomial test comparing KMed Sharpe and DJI Sharpe
# Number of successes: 686 out of 1049: 65.40
# P-value: 6.106808314543971e-24
# Reject the null hypothesis: KMed Sharpe has significantly more periods with higher values than DJI Sharpe.

# %%
dji.prices
# Out:
#                      DJI
# Date
# 2013-01-02  13412.549805
# 2013-01-03  13391.360352
# 2013-01-04  13435.209961
# 2013-01-07  13384.290039
# 2013-01-08  13328.849609
# ...                  ...
# 2023-12-22  37385.968750
# 2023-12-26  37545.328125
# 2023-12-27  37656.519531
# 2023-12-28  37710.101562
# 2023-12-29  37689.539062
#
# [2768 rows x 1 columns]

# %%
sim_port = Portfolio('2020-11-01', '2024-01-01', tickers = eval(avg5s.loc['2020-11-02'].portfolio))


fig, ax = plt.subplots(figsize=(20, 6))
dji.prices.loc['2020-11-01': '2024-01-01'].plot(ax = ax)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(15, 6))
dji.prices.loc['2020-11-01': '2024-01-01'].plot()
# Out:
# <Axes: xlabel='Date'>
